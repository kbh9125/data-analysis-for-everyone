# %%
import csv

f = open('age.csv',encoding = 'cp949')
data = csv.reader(f)

result = []
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요: ')

for row in data :
    if name in row[0] :
        for i in row[3:] :
            result.append(int(i))
            
print(result)

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.style.use('ggplot')
#plt.rc('font', family = 'Nanum Gothic Regular')

path = '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
print(font_name)
plt.rc('font', family=font_name)

plt.title(name + ' 지역의 인구 구조')
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요: 신도림
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]
# NanumGothicCoding

# %%
import matplotlib    
import matplotlib.font_manager

[f.name for f in matplotlib.font_manager.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# ['NanumBarunGothic',
#  'NanumMyeongjo',
#  'NanumMyeongjo',
#  'NanumSquare',
#  'NanumBarunGothic',
#  'NanumGothicCoding',
#  'NanumGothic',
#  'NanumSquare',
#  'NanumGothicCoding',
#  'NanumSquareRound',
#  'NanumGothic',
#  'NanumSquareRound']

# %%
import csv

f = open('age.csv',encoding = 'cp949')
data = csv.reader(f)

result = []
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요: ')

for row in data :
    if name in row[0] :
        for i in row[3:] :
            result.append(int(i))
            
print(result)

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.style.use('ggplot')
plt.rc('font', family = 'NanumGothicCoding')
plt.title(name + ' 지역의 인구 구조')
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요: 신도림
# [326, 334, 406, 413, 389, 408, 417, 434, 411, 387, 420, 383, 354, 357, 340, 338, 349, 339, 407, 380, 390, 453, 424, 516, 451, 466, 448, 484, 471, 476, 558, 541, 579, 619, 638, 740, 756, 792, 745, 789, 671, 687, 700, 636, 726, 691, 657, 619, 649, 585, 579, 470, 522, 534, 563, 445, 511, 569, 572, 513, 532, 456, 426, 497, 379, 384, 399, 279, 289, 276, 268, 271, 223, 170, 150, 154, 177, 140, 126, 114, 121, 97, 86, 80, 59, 48, 44, 43, 28, 29, 22, 15, 13, 12, 5, 8, 5, 4, 2, 3, 7]

# %%
import matplotlib.pyplot as plt

#plt.bar([0,1,2,4,6,10],[1,2,3,5,6,7])
plt.bar(range(6),[1,2,3,5,6,7])
plt.show()

# %%
import csv

f = open('age.csv',encoding = 'cp949')
data = csv.reader(f)

result = []

for row in data :
    if '신도림' in row[0] :
        for i in row[3:] :
            result.append(int(i))
            
import matplotlib.pyplot as plt
#plt.bar(range(101),result)
plt.barh(range(101),result)
plt.show()

# %%
import csv
f = open('gender.csv', encoding = 'cp949')
data = csv.reader(f)

m = []
f = []

for row in data :
    if '신도림' in row[0] :
        print(row)
        for i in range(0,101) :
            m.append(int(row[i+3]))
            f.append(int(row[-(i+1)]))

f.reverse()

print(m)
print(f)
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '18,236', '18,236', '165', '185', '221', '209', '192', '209', '189', '210', '217', '197', '210', '198', '198', '189', '171', '156', '183', '178', '205', '175', '203', '218', '210', '257', '222', '249', '203', '239', '227', '212', '250', '237', '270', '309', '308', '387', '366', '367', '349', '390', '324', '330', '342', '306', '363', '348', '331', '321', '302', '275', '264', '253', '258', '266', '280', '224', '280', '257', '277', '246', '270', '217', '194', '248', '180', '193', '177', '130', '148', '159', '154', '141', '112', '77', '86', '70', '86', '69', '57', '47', '51', '44', '26', '32', '20', '9', '19', '13', '5', '6', '3', '3', '3', '2', '1', '3', '1', '1', '1', '0', '1', '19,009', '19,009', '152', '164', '195', '195', '200', '206', '227', '222', '195', '198', '201', '190', '161', '174', '161', '178', '166', '163', '203', '193', '192', '220', '218', '256', '235', '216', '239', '255', '229', '268', '305', '296', '306', '318', '336', '369', '393', '441', '382', '396', '355', '357', '355', '321', '366', '351', '303', '327', '329', '299', '299', '246', '247', '294', '240', '222', '258', '307', '280', '268', '263', '238', '224', '269', '201', '185', '225', '140', '143', '120', '118', '143', '86', '85', '74', '84', '87', '69', '73', '67', '63', '53', '60', '46', '44', '31', '29', '29', '21', '25', '18', '12', '11', '10', '3', '7', '3', '2', '1', '3', '6']
# [165, 185, 221, 209, 192, 209, 189, 210, 217, 197, 210, 198, 198, 189, 171, 156, 183, 178, 205, 175, 203, 218, 210, 257, 222, 249, 203, 239, 227, 212, 250, 237, 270, 309, 308, 387, 366, 367, 349, 390, 324, 330, 342, 306, 363, 348, 331, 321, 302, 275, 264, 253, 258, 266, 280, 224, 280, 257, 277, 246, 270, 217, 194, 248, 180, 193, 177, 130, 148, 159, 154, 141, 112, 77, 86, 70, 86, 69, 57, 47, 51, 44, 26, 32, 20, 9, 19, 13, 5, 6, 3, 3, 3, 2, 1, 3, 1, 1, 1, 0, 1]
# [152, 164, 195, 195, 200, 206, 227, 222, 195, 198, 201, 190, 161, 174, 161, 178, 166, 163, 203, 193, 192, 220, 218, 256, 235, 216, 239, 255, 229, 268, 305, 296, 306, 318, 336, 369, 393, 441, 382, 396, 355, 357, 355, 321, 366, 351, 303, 327, 329, 299, 299, 246, 247, 294, 240, 222, 258, 307, 280, 268, 263, 238, 224, 269, 201, 185, 225, 140, 143, 120, 118, 143, 86, 85, 74, 84, 87, 69, 73, 67, 63, 53, 60, 46, 44, 31, 29, 29, 21, 25, 18, 12, 11, 10, 3, 7, 3, 2, 1, 3, 6]

# %%
import csv
f = open('gender.csv', encoding = 'cp949')
data = csv.reader(f)

m = []
f = []

for row in data :
    if '신도림' in row[0] :
        print(row)
        for i in row[3:104] :
            m.append(int(i))
        for i in row[106:] :
            f.append(int(i))

print(m)
print(f)

import matplotlib.pyplot as plt

plt.barh(range(101),m)
plt.barh(range(101),f)

plt.show()
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '18,236', '18,236', '165', '185', '221', '209', '192', '209', '189', '210', '217', '197', '210', '198', '198', '189', '171', '156', '183', '178', '205', '175', '203', '218', '210', '257', '222', '249', '203', '239', '227', '212', '250', '237', '270', '309', '308', '387', '366', '367', '349', '390', '324', '330', '342', '306', '363', '348', '331', '321', '302', '275', '264', '253', '258', '266', '280', '224', '280', '257', '277', '246', '270', '217', '194', '248', '180', '193', '177', '130', '148', '159', '154', '141', '112', '77', '86', '70', '86', '69', '57', '47', '51', '44', '26', '32', '20', '9', '19', '13', '5', '6', '3', '3', '3', '2', '1', '3', '1', '1', '1', '0', '1', '19,009', '19,009', '152', '164', '195', '195', '200', '206', '227', '222', '195', '198', '201', '190', '161', '174', '161', '178', '166', '163', '203', '193', '192', '220', '218', '256', '235', '216', '239', '255', '229', '268', '305', '296', '306', '318', '336', '369', '393', '441', '382', '396', '355', '357', '355', '321', '366', '351', '303', '327', '329', '299', '299', '246', '247', '294', '240', '222', '258', '307', '280', '268', '263', '238', '224', '269', '201', '185', '225', '140', '143', '120', '118', '143', '86', '85', '74', '84', '87', '69', '73', '67', '63', '53', '60', '46', '44', '31', '29', '29', '21', '25', '18', '12', '11', '10', '3', '7', '3', '2', '1', '3', '6']
# [165, 185, 221, 209, 192, 209, 189, 210, 217, 197, 210, 198, 198, 189, 171, 156, 183, 178, 205, 175, 203, 218, 210, 257, 222, 249, 203, 239, 227, 212, 250, 237, 270, 309, 308, 387, 366, 367, 349, 390, 324, 330, 342, 306, 363, 348, 331, 321, 302, 275, 264, 253, 258, 266, 280, 224, 280, 257, 277, 246, 270, 217, 194, 248, 180, 193, 177, 130, 148, 159, 154, 141, 112, 77, 86, 70, 86, 69, 57, 47, 51, 44, 26, 32, 20, 9, 19, 13, 5, 6, 3, 3, 3, 2, 1, 3, 1, 1, 1, 0, 1]
# [152, 164, 195, 195, 200, 206, 227, 222, 195, 198, 201, 190, 161, 174, 161, 178, 166, 163, 203, 193, 192, 220, 218, 256, 235, 216, 239, 255, 229, 268, 305, 296, 306, 318, 336, 369, 393, 441, 382, 396, 355, 357, 355, 321, 366, 351, 303, 327, 329, 299, 299, 246, 247, 294, 240, 222, 258, 307, 280, 268, 263, 238, 224, 269, 201, 185, 225, 140, 143, 120, 118, 143, 86, 85, 74, 84, 87, 69, 73, 67, 63, 53, 60, 46, 44, 31, 29, 29, 21, 25, 18, 12, 11, 10, 3, 7, 3, 2, 1, 3, 6]

# %%
import csv
f = open('gender.csv', encoding = 'cp949')
data = csv.reader(f)

m = []
f = []

name = input('찾고 싶은 지역의 이름을 알려주세요: ')

for row in data :
    if name in row[0] :
        print(row)
        for i in row[3:104] :
            m.append(-int(i))
        for i in row[106:] :
            f.append(int(i))

print(m)
print(f)

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi = 300)
plt.rc('font', family = 'NanumGothicCoding')
plt.rcParams['axes.unicode_minus'] = False

plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101),m, label = '남성')
plt.barh(range(101),f, label = '여성')

plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요: 1147064000
# ['서울특별시 양천구 신정3동(1147064000)', '23,613', '23,613', '136', '160', '178', '219', '216', '208', '232', '253', '301', '236', '302', '277', '274', '256', '278', '306', '302', '345', '342', '382', '339', '343', '344', '340', '323', '319', '308', '277', '237', '231', '222', '259', '234', '285', '261', '340', '355', '390', '378', '376', '361', '336', '372', '401', '464', '422', '479', '479', '491', '468', '479', '446', '389', '383', '393', '349', '339', '371', '377', '342', '301', '323', '303', '274', '247', '189', '218', '182', '196', '198', '174', '187', '148', '106', '142', '120', '156', '102', '85', '87', '65', '53', '54', '45', '28', '28', '23', '19', '6', '16', '14', '1', '5', '3', '2', '3', '1', '0', '1', '1', '2', '24,570', '24,570', '132', '169', '172', '197', '214', '181', '252', '239', '286', '252', '287', '257', '233', '231', '231', '279', '299', '310', '344', '330', '317', '294', '282', '319', '293', '288', '261', '284', '241', '250', '257', '284', '274', '259', '269', '333', '394', '403', '402', '425', '392', '396', '349', '417', '482', '460', '478', '518', '534', '485', '492', '422', '454', '381', '386', '338', '388', '371', '427', '379', '364', '353', '296', '321', '255', '237', '286', '200', '209', '225', '176', '182', '159', '148', '144', '124', '161', '132', '118', '117', '82', '105', '80', '78', '68', '69', '50', '50', '38', '40', '31', '20', '21', '12', '5', '11', '7', '6', '4', '4', '9']
# [-136, -160, -178, -219, -216, -208, -232, -253, -301, -236, -302, -277, -274, -256, -278, -306, -302, -345, -342, -382, -339, -343, -344, -340, -323, -319, -308, -277, -237, -231, -222, -259, -234, -285, -261, -340, -355, -390, -378, -376, -361, -336, -372, -401, -464, -422, -479, -479, -491, -468, -479, -446, -389, -383, -393, -349, -339, -371, -377, -342, -301, -323, -303, -274, -247, -189, -218, -182, -196, -198, -174, -187, -148, -106, -142, -120, -156, -102, -85, -87, -65, -53, -54, -45, -28, -28, -23, -19, -6, -16, -14, -1, -5, -3, -2, -3, -1, 0, -1, -1, -2]
# [132, 169, 172, 197, 214, 181, 252, 239, 286, 252, 287, 257, 233, 231, 231, 279, 299, 310, 344, 330, 317, 294, 282, 319, 293, 288, 261, 284, 241, 250, 257, 284, 274, 259, 269, 333, 394, 403, 402, 425, 392, 396, 349, 417, 482, 460, 478, 518, 534, 485, 492, 422, 454, 381, 386, 338, 388, 371, 427, 379, 364, 353, 296, 321, 255, 237, 286, 200, 209, 225, 176, 182, 159, 148, 144, 124, 161, 132, 118, 117, 82, 105, 80, 78, 68, 69, 50, 50, 38, 40, 31, 20, 21, 12, 5, 11, 7, 6, 4, 4, 9]
